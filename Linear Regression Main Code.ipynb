# %%
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('train.csv')
data.head()
# Out:
#       x          y
# 0  24.0  21.549452
# 1  50.0  47.464463
# 2  15.0  17.218656
# 3  38.0  36.586398
# 4  87.0  87.288984

# %%
data.dropna(inplace = True)
df = data.copy() # important for de-normalize process

# %%
data.describe()
# Out:
#                 x           y
# count  699.000000  699.000000
# mean    50.014306   49.939869
# std     28.954560   29.109217
# min      0.000000   -3.839981
# 25%     25.000000   24.929968
# 50%     49.000000   48.973020
# 75%     75.000000   74.929911
# max    100.000000  108.871618

# %%
data.dtypes
# Out:
# x    float64
# y    float64
# dtype: object

# %%
f = px.scatter(x = data['x'],y = data['y'])
f.show()
# Out:
# <div>                            <div id="c6fcc403-cdbd-47fc-b1fc-80e3fa97d8c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6fcc403-cdbd-47fc-b1fc-80e3fa97d8c3")) {                    Plotly.newPlot(                        "c6fcc403-cdbd-47fc-b1fc-80e3fa97d8c3",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[24.0,50.0,15.0,38.0,87.0,36.0,12.0,81.0,25.0,5.0,16.0,16.0,24.0,39.0,54.0,60.0,26.0,73.0,29.0,31.0,68.0,87.0,58.0,54.0,84.0,58.0,49.0,20.0,90.0,48.0,4.0,25.0,42.0,0.0,60.0,93.0,39.0,7.0,21.0,68.0,84.0,0.0,58.0,19.0,36.0,19.0,59.0,51.0,19.0,33.0,85.0,44.0,5.0,59.0,14.0,9.0,75.0,69.0,10.0,17.0,58.0,74.0,21.0,51.0,19.0,50.0,24.0,0.0,12.0,75.0,21.0,64.0,5.0,58.0,32.0,41.0,7.0,4.0,5.0,49.0,90.0,3.0,11.0,32.0,83.0,25.0,83.0,26.0,76.0,95.0,53.0,77.0,42.0,25.0,54.0,55.0,0.0,73.0,35.0,86.0,90.0,13.0,46.0,46.0,32.0,8.0,71.0,28.0,24.0,56.0,49.0,79.0,90.0,89.0,41.0,27.0,58.0,26.0,31.0,70.0,71.0,39.0,7.0,48.0,56.0,45.0,41.0,3.0,37.0,24.0,68.0,47.0,27.0,68.0,74.0,95.0,79.0,21.0,95.0,54.0,56.0,80.0,26.0,25.0,8.0,95.0,94.0,54.0,7.0,99.0,36.0,48.0,65.0,42.0,93.0,86.0,26.0,51.0,100.0,94.0,6.0,24.0,75.0,7.0,53.0,73.0,16.0,80.0,77.0,89.0,80.0,55.0,19.0,56.0,47.0,56.0,2.0,82.0,57.0,44.0,26.0,52.0,41.0,44.0,3.0,31.0,97.0,21.0,17.0,7.0,61.0,10.0,52.0,10.0,65.0,71.0,4.0,24.0,26.0,51.0,42.0,62.0,74.0,77.0,3.0,50.0,24.0,37.0,58.0,52.0,27.0,14.0,100.0,72.0,5.0,71.0,54.0,84.0,42.0,54.0,74.0,54.0,53.0,78.0,97.0,49.0,71.0,48.0,51.0,89.0,99.0,93.0,49.0,18.0,65.0,83.0,100.0,41.0,52.0,29.0,97.0,7.0,51.0,58.0,50.0,67.0,89.0,76.0,35.0,99.0,31.0,52.0,11.0,66.0,50.0,39.0,60.0,35.0,53.0,14.0,49.0,16.0,76.0,13.0,51.0,70.0,98.0,86.0,100.0,46.0,51.0,50.0,91.0,48.0,81.0,38.0,40.0,79.0,96.0,60.0,70.0,44.0,11.0,6.0,5.0,72.0,55.0,95.0,41.0,25.0,1.0,55.0,4.0,48.0,55.0,75.0,68.0,100.0,25.0,75.0,34.0,38.0,92.0,21.0,88.0,75.0,76.0,44.0,10.0,21.0,16.0,32.0,13.0,26.0,70.0,77.0,77.0,88.0,35.0,24.0,17.0,91.0,32.0,36.0,89.0,69.0,30.0,6.0,22.0,67.0,9.0,74.0,50.0,85.0,3.0,0.0,59.0,62.0,17.0,90.0,23.0,19.0,93.0,14.0,58.0,87.0,37.0,20.0,35.0,63.0,56.0,62.0,98.0,90.0,51.0,93.0,22.0,38.0,13.0,98.0,99.0,31.0,94.0,73.0,37.0,23.0,11.0,88.0,47.0,79.0,91.0,71.0,10.0,39.0,92.0,99.0,28.0,32.0,32.0,75.0,99.0,27.0,64.0,98.0,38.0,46.0,13.0,96.0,9.0,34.0,49.0,1.0,50.0,94.0,27.0,20.0,12.0,45.0,91.0,61.0,10.0,47.0,33.0,84.0,24.0,48.0,48.0,9.0,93.0,99.0,8.0,20.0,38.0,78.0,81.0,42.0,95.0,78.0,44.0,68.0,87.0,58.0,52.0,26.0,75.0,48.0,71.0,77.0,34.0,24.0,70.0,29.0,76.0,98.0,28.0,87.0,9.0,87.0,33.0,64.0,17.0,49.0,95.0,75.0,89.0,81.0,25.0,47.0,50.0,5.0,68.0,84.0,8.0,41.0,26.0,89.0,78.0,34.0,92.0,27.0,12.0,2.0,22.0,0.0,26.0,50.0,84.0,70.0,66.0,42.0,19.0,94.0,71.0,19.0,16.0,49.0,29.0,29.0,86.0,50.0,86.0,30.0,23.0,20.0,16.0,57.0,8.0,8.0,62.0,55.0,30.0,86.0,62.0,51.0,61.0,86.0,61.0,21.0,81.0,97.0,5.0,61.0,47.0,98.0,30.0,63.0,0.0,100.0,18.0,30.0,98.0,16.0,22.0,55.0,43.0,75.0,91.0,46.0,85.0,55.0,36.0,49.0,94.0,43.0,22.0,37.0,24.0,95.0,61.0,75.0,68.0,58.0,5.0,53.0,80.0,83.0,25.0,34.0,26.0,90.0,60.0,49.0,19.0,92.0,29.0,8.0,57.0,29.0,19.0,81.0,50.0,15.0,70.0,39.0,43.0,21.0,98.0,86.0,16.0,25.0,31.0,93.0,67.0,49.0,25.0,88.0,54.0,21.0,8.0,32.0,35.0,67.0,90.0,59.0,15.0,67.0,42.0,44.0,77.0,68.0,36.0,11.0,10.0,65.0,98.0,98.0,49.0,31.0,56.0,70.0,91.0,25.0,54.0,39.0,91.0,3.0,22.0,2.0,2.0,65.0,71.0,42.0,76.0,43.0,8.0,86.0,87.0,3.0,58.0,62.0,89.0,95.0,28.0,0.0,1.0,49.0,21.0,46.0,11.0,89.0,37.0,29.0,44.0,96.0,16.0,74.0,35.0,42.0,16.0,56.0,18.0,100.0,54.0,92.0,63.0,81.0,73.0,48.0,1.0,85.0,14.0,25.0,45.0,98.0,97.0,58.0,93.0,88.0,89.0,47.0,6.0,34.0,30.0,16.0,86.0,40.0,52.0,15.0,4.0,95.0,99.0,35.0,58.0,10.0,16.0,53.0,58.0,42.0, ...

# %% [markdown]
# # Normalize

# %%
def normalize(col):
    
    col = (col - col.min())/(col.max()-col.min())
    return col
    
data['x'] = normalize(data['x'])
data['y'] =  normalize(data['y'])

# %% [markdown]
# # Cost function

# %%
x0 = [1] * len(data)
x1 = data['x']

X = np.array([x0 , x1]).T
W = np.array([0 , 11 ])

# %%
X
# Out:
# array([[1.  , 0.24],
#        [1.  , 0.5 ],
#        [1.  , 0.15],
#        ...,
#        [1.  , 0.82],
#        [1.  , 0.66],
#        [1.  , 0.97]])

# %%
def costFunction (X,y,W) :
    h = X.dot(W)
    J = np.sum(((h - y) **2) / (2 * len(y)))
    return J

# %%
costWithoutGradient = costFunction(X , data['y'] , W)

# %%
costWithoutGradient
# Out:
# 16.90303900268054

# %%
def gradientFunction(X , Y , W , alpha = 0.01 , iterations = 40000):
        
    costH = []
    length = len(Y)
    
    for i in range (0,iterations):
        if i % 1000== 0 :
            print("Iteration %d: "%i)
            print(costFunction(X,Y,W))
            
            
        h = X.dot(W)
        diff = h - Y
        g = X.T.dot(diff) / length # gradient
        
        W = W - alpha * g
        
        cost = costFunction(X,Y,W)
        costH.append(cost)
        
    return W , costH

# %%
w2 , cost = gradientFunction(X , data['y'] , W)
# Out:
# Iteration 0:
# 16.90303900268054
# Iteration 1000:
# 0.7029020997507346
# Iteration 2000:
# 0.1877965417604989
# Iteration 3000:
# 0.05034055758881528
# Iteration 4000:
# 0.013660410586223993
# Iteration 5000:
# 0.003872308654981479
# Iteration 6000:
# 0.0012603523994728443
# Iteration 7000:
# 0.0005633515377516722
# Iteration 8000:
# 0.000377356768422945
# Iteration 9000:
# 0.00032772404037692673
# Iteration 10000:
# 0.00031447954053329986
# Iteration 11000:
# 0.0003109452440516476
# Iteration 12000:
# 0.0003100021165823062
# Iteration 13000:
# 0.0003097504428961724
# Iteration 14000:
# 0.0003096832837407547
# Iteration 15000:
# 0.0003096653623115194
# Iteration 16000:
# 0.00030966057997582985
# Iteration 17000:
# 0.0003096593038089379
# Iteration 18000:
# 0.0003096589632636391
# Iteration 19000:
# 0.0003096588723890824
# Iteration 20000:
# 0.00030965884813919536
# Iteration 21000:
# 0.00030965884166810986
# Iteration 22000:
# 0.00030965883994129987
# Iteration 23000:
# 0.0003096588394805004
# Iteration 24000:
# 0.00030965883935753604
# Iteration 25000:
# 0.000309658839324723
# Iteration 26000:
# 0.00030965883931596675
# Iteration 27000:
# 0.0003096588393136302
# Iteration 28000:
# 0.00030965883931300666
# Iteration 29000:
# 0.0003096588393128403
# Iteration 30000:
# 0.0003096588393127959
# Iteration 31000:
# 0.0003096588393127841
# Iteration 32000:
# 0.0003096588393127808
# Iteration 33000:
# 0.00030965883931278007
# Iteration 34000:
# 0.00030965883931277985
# Iteration 35000:
# 0.00030965883931277974
# Iteration 36000:
# 0.00030965883931277963
# Iteration 37000:
# 0.00030965883931277974
# Iteration 38000:
# 0.00030965883931277974
# Iteration 39000:
# 0.0003096588393127797

# %%
w2 # coefficients
# Out:
# array([0.0331174 , 0.88780249])

# %%
data['pred'] = X.dot(w2)
data
# Out:
#         x         y      pred
# 0    0.24  0.225260  0.246190
# 1    0.50  0.455183  0.477019
# 2    0.15  0.186836  0.166288
# 3    0.38  0.358671  0.370482
# 4    0.87  0.808515  0.805506
# ..    ...       ...       ...
# 695  0.58  0.553936  0.548043
# 696  0.93  0.873602  0.858774
# 697  0.82  0.820180  0.761115
# 698  0.66  0.598773  0.619067
# 699  0.97  0.876709  0.894286
#
# [699 rows x 3 columns]

# %% [markdown]
# # Testing

# %%
test = pd.read_csv('test.csv')
df_test = test.copy()

# %%
test['x'] = normalize(test['x'])
test['y'] = normalize(test['y'])

# %%
def testFunction (X) :
    
    predict = w2[0] * 1 + w2[1] * X 
    
    return predict

# %%
test['prediction'] = testFunction(test['x'])

# %%
fig1 = px.line(test, x="x", y="prediction", title='Line of Linear Regression Model')
fig2 = px.scatter(x = test['x'],y = test['y'])

fig = go.Figure(data = fig1.data + fig2.data)
fig.show()
# Out:
# <div>                            <div id="52b52e37-56f0-4cbb-aec1-5b31ef7ee950" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52b52e37-56f0-4cbb-aec1-5b31ef7ee950")) {                    Plotly.newPlot(                        "52b52e37-56f0-4cbb-aec1-5b31ef7ee950",                        [{"hovertemplate":"x=%{x}<br>prediction=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[0.77,0.21,0.22,0.2,0.36,0.15,0.62,0.95,0.2,0.05,0.04,0.19,0.96,0.62,0.36,0.15,0.65,0.14,0.87,0.69,0.89,0.51,0.89,0.27,0.97,0.58,0.79,0.21,0.93,0.27,0.99,0.31,0.33,0.8,0.28,0.47,0.53,0.69,0.28,0.33,0.91,0.71,0.5,0.76,0.04,0.37,0.7,0.68,0.4,0.35,0.94,0.88,0.52,0.31,0.59,0.0,0.39,0.64,0.69,0.57,0.13,0.72,0.76,0.61,0.82,0.18,0.41,0.5,0.55,0.13,0.46,0.13,0.79,0.53,0.15,0.28,0.81,0.69,0.52,0.84,0.68,0.27,0.56,0.48,0.4,0.39,0.82,1.0,0.59,0.43,0.67,0.38,0.63,0.91,0.6,0.14,0.21,0.87,0.73,0.32,0.02,0.82,0.19,0.74,0.42,0.12,0.01,0.9,0.89,0.0,0.41,0.16,0.94,0.97,0.66,0.24,0.17,0.9,0.13,0.0,0.64,0.96,0.98,0.12,0.41,0.47,0.78,0.2,0.89,0.29,0.64,0.75,0.12,0.25,0.28,0.3,0.65,0.59,0.64,0.53,0.71,0.97,0.73,0.09,0.12,0.63,0.99,0.6,0.35,0.02,0.6,0.32,0.94,0.84,0.63,0.22,0.81,0.93,0.33,0.07,0.42,0.46,0.54,0.16,0.49,0.43,0.95,0.66,0.21,0.35,0.8,0.37,0.54,0.56,0.01,0.32,0.58,0.32,0.46,0.72,0.17,0.97,0.93,0.91,0.37,0.04,0.54,0.51,0.27,0.46,0.92,0.73,0.77,0.91,0.61,0.99,0.04,0.72,0.19,0.57,0.78,0.26,0.74,0.9,0.66,0.13,0.4,0.77,0.67,0.75,0.23,0.45,0.59,0.44,0.23,0.55,0.55,0.95,0.12,0.04,0.07,1.0,0.48,0.42,0.96,0.39,1.0,0.87,0.14,0.14,0.37,0.05,0.88,0.91,0.65,0.74,0.56,0.16,0.05,0.28,0.92,0.46,0.54,0.39,0.44,0.31,0.68,0.86,0.9,0.38,0.21,0.95,0.56,0.6,0.65,0.78,0.89,0.06,0.67,0.36,0.16,1.0,0.45,0.73,0.57,0.2,0.76,0.34,0.55,0.72,0.55,0.08,0.56,0.72,0.58,0.06,0.96,0.23,0.58,0.23,0.19,0.25,0.64,0.21,0.59,0.19,0.16,0.42,0.43,0.61,0.92,0.11,0.41,0.01,0.08,0.71,0.46,0.55,0.62,0.47],"xaxis":"x","y":[0.716725319089008,0.2195559268172541,0.22843395167924974,0.21067790195525854,0.3527262997471882,0.16628777764528047,0.583554946159074,0.876529766604929,0.21067790195525854,0.07750752902532443,0.06862950416332883,0.2017998770932629,0.8854077914669245,0.583554946159074,0.3527262997471882,0.16628777764528047,0.6101890207450608,0.1574097527832849,0.8055055677089641,0.6457011201930432,0.8232616174329553,0.48589667267712233,0.8232616174329553,0.27282407598922775,0.8942858163289201,0.5480428467110915,0.7344813688129993,0.2195559268172541,0.8587737168809378,0.27282407598922775,0.9120418660529114,0.3083361754372102,0.3260922251612014,0.7433593936749949,0.2817021008512234,0.4503845732291399,0.5036527224011135,0.6457011201930432,0.2817021008512234,0.3260922251612014,0.8410176671569466,0.6634571699170344,0.4770186478151267,0.7078472942270124,0.06862950416332883,0.36160432460918385,0.6545791450550388,0.6368230953310476,0.38823839919517067,0.3438482748851926,0.8676517417429334,0.8143835925709597,0.49477469753911796,0.3083361754372102,0.5569208715730871,0.033117404715346396,0.37936037433317504,0.6013109958830652,0.6457011201930432,0.5391648218490959,0.14853172792128927,0.67233519477903,0.7078472942270124,0.5746769212970784,0.7611154433989861,0.1929218522312673,0.39711642405716624,0.4770186478151267,0.5214087721251047,0.14853172792128927,0.4415065483671443,0.14853172792128927,0.7344813688129993,0.5036527224011135,0.16628777764528047,0.2817021008512234,0.7522374185369906,0.6457011201930432,0.49477469753911796,0.7788714931229773,0.6368230953310476,0.27282407598922775,0.5302867969871004,0.45926259809113545,0.38823839919517067,0.37936037433317504,0.7611154433989861,0.920919890914907,0.5569208715730871,0.41487247378115744,0.627945070469052,0.3704823494711 ...

# %%
test
# Out:
#         x         y  prediction
# 0    0.77  0.763279    0.716725
# 1    0.21  0.244317    0.219556
# 2    0.22  0.266617    0.228434
# 3    0.20  0.195538    0.210678
# 4    0.36  0.415531    0.352726
# ..    ...       ...         ...
# 295  0.71  0.660315    0.663457
# 296  0.46  0.465825    0.441507
# 297  0.55  0.527771    0.521409
# 298  0.62  0.612188    0.583555
# 299  0.47  0.512814    0.450385
#
# [300 rows x 3 columns]

# %%
# for calculating error and r-square score we must do de-normalize
def deNormalize(col,maxi,mini):
    c = col * (maxi-mini) + mini
    
    return c
    
test['x'] = deNormalize(test['x'],df_test['x'].max(),df_test['y'].min())
test['y'] =  deNormalize(test['y'],df_test['x'].max(),df_test['y'].min())
test['prediction'] =  deNormalize(test['prediction'],df_test['x'].max(),df_test['y'].min())

# %%
test
# Out:
#              x          y  prediction
# 0    76.202387  75.507018   70.690168
# 1    18.260372  21.811097   19.249103
# 2    19.295051  24.118384   20.167694
# 3    17.225693  16.763974   18.330513
# 4    33.780554  39.526280   33.027960
# ..         ...        ...         ...
# 295  69.994314  64.853514   65.178626
# 296  44.127343  44.730058   42.213864
# 297  53.439452  51.139429   50.481178
# 298  60.682204  59.873915   56.911312
# 299  45.162022  49.591894   43.132455
#
# [300 rows x 3 columns]

# %%
def error(Y , Pred) :
    err = abs(Y - Pred)
    return err

# %%
test['error'] = error(test['y'],test['prediction'])

# %%
a = test['error'].sum()

# %%
errorr = a / len(test['prediction'])

# %%
print(errorr) # mean_absolute_error
# Out:
# 2.8356186647913715

# %% [raw]
# Calculating r-square error

# %%
def residual_error(col):
    col = col*col
    return col
test['E^2'] = test['error'].apply(residual_error)

# %%
def mean_error(col):
    col = col - col.mean()
    col = col*col
    
    return col
test['mean_error'] = mean_error(test['y'])

# %%
r_square_error = 1 - (test['E^2'].sum() / test['mean_error'].sum())

# %%
r_square_error
# Out:
# 0.9834725922456193

# %%
test
# Out:
#              x          y  prediction     error        E^2   mean_error
# 0    76.202387  75.507018   70.690168  4.816850  23.202040   734.693022
# 1    18.260372  21.811097   19.249103  2.561994   6.563811   707.065302
# 2    19.295051  24.118384   20.167694  3.950690  15.607955   589.684113
# 3    17.225693  16.763974   18.330513  1.566539   2.454045  1000.951820
# 4    33.780554  39.526280   33.027960  6.498320  42.228161    78.774796
# ..         ...        ...         ...       ...        ...          ...
# 295  69.994314  64.853514   65.178626  0.325112   0.105698   270.658997
# 296  44.127343  44.730058   42.213864  2.516193   6.331229    13.481665
# 297  53.439452  51.139429   50.481178  0.658251   0.433294     7.494632
# 298  60.682204  59.873915   56.911312  2.962603   8.777017   131.609496
# 299  45.162022  49.591894   43.132455  6.459439  41.724359     1.416333
#
# [300 rows x 6 columns]

# %% [markdown]
# # Model creating with library

# %%
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score

# %%
df
df.dropna(inplace = True)

# %%
df
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [699 rows x 2 columns]

# %%
model = LinearRegression()

# %%
X = df[['x']]
Y = df[['y']]

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
df_test
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
# making predictions
predictions = model.predict(df_test[['x']])

# %% [markdown]
# # Comparing

# %%
# model evaluation
print("Result of library >>> ")
print(
  'mean_absolute_error : ', mean_absolute_error(df_test[['y']], predictions))
print("r-square error : " , r2_score(df_test[['y']] , predictions) )
# Out:
# Result of library >>>
# mean_absolute_error :  2.415771850041258
# r-square error :  0.9888014444327563

# %%
print("Result of our writing main code >>> ")
print(
  'mean_absolute_error : ', errorr)
print("r-square error : " , r_square_error )
# Out:
# Result of our writing main code >>>
# mean_absolute_error :  2.8356186647913715
# r-square error :  0.9834725922456193
